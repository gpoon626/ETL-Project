# %%
# !pip3 install pyspark
# !pip3 install findspark
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached pyspark-3.3.0.tar.gz (281.3 MB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached py4j-0.10.9.5-py2.py3-none-any.whl (199 kB)
# ...
#   Created wheel for pyspark: filename=pyspark-3.3.0-py2.py3-none-any.whl size=281764027 sha256=442049519e5dcf30c43e4936c5069fcbd4ae3ebee5469ff8fc7681a3057b3d88
#   Stored in directory: /Users/thomaslaurel/Library/Caches/pip/wheels/1d/27/68/1382001655ef41217e1dd34d59aa777612135379bab64279e9
# Successfully built pyspark
# ...
#
# [notice] A new release of pip available: 22.2.2 -> 22.3
# ...

# %%
# !pip3 install matplotlib
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 9.6 MB/s eta 0:00:00:00:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.2/241.2 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 960.8/960.8 kB 4.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.4/65.4 kB 657.6 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 7.4 MB/s eta 0:00:0000:0100:01m
# ...
#   WARNING: The scripts fonttools, pyftmerge, pyftsubset and ttx are installed in '/Users/thomaslaurel/Library/Python/3.8/bin' which is not on PATH.
# ...

# %%
# !pip3 install seaborn
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 kB 3.8 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 5.2 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.6.1
#     Uninstalling matplotlib-3.6.1:
#       Successfully uninstalled matplotlib-3.6.1
# ...
#
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip

# %%
import pyspark

# %%
import findspark
import json
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
df = pd.read_csv("/Users/thomaslaurel/Desktop/jump/ETLProject/ETL-Project-1/Spotify-2000.csv")

# %%
df.head()
# Out:
#    Index                   Title             Artist            Top Genre  \
# 0      1                 Sunrise        Norah Jones      adult standards
# 1      2             Black Night        Deep Purple           album rock
# 2      3          Clint Eastwood           Gorillaz  alternative hip hop
# 3      4           The Pretender       Foo Fighters    alternative metal
# 4      5  Waitin' On A Sunny Day  Bruce Springsteen         classic rock
#
#    Year  Beats Per Minute (BPM)  Energy  Danceability  Loudness (dB)  \
# 0  2004                     157      30            53            -14
# 1  2000                     135      79            50            -11
# 2  2001                     168      69            66             -9
# 3  2007                     173      96            43             -4
# 4  2002                     106      82            58             -5
#
#    Liveness  Valence Length (Duration)  Acousticness  Speechiness  Popularity
# ...

# %%
df_1 = df[["Index","Artist","Title","Top Genre","Year","Danceability","Popularity","Energy","Length (Duration)","Beats Per Minute (BPM)"]]
df_1
# Out:
#       Index                    Artist                   Title  \
# 0         1               Norah Jones                 Sunrise
# 1         2               Deep Purple             Black Night
# 2         3                  Gorillaz          Clint Eastwood
# 3         4              Foo Fighters           The Pretender
# 4         5         Bruce Springsteen  Waitin' On A Sunny Day
# ...     ...                       ...                     ...
# 1989   1990             Elvis Presley        Heartbreak Hotel
# 1990   1991             Elvis Presley               Hound Dog
# 1991   1992               Chuck Berry         Johnny B. Goode
# 1992   1993  The Dave Brubeck Quartet               Take Five
# 1993   1994               Fats Domino          Blueberry Hill
#
#                 Top Genre  Year  Danceability  Popularity  Energy  \
# 0         adult standards  2004            53          71      30
# 1              album rock  2000            50          39      79
# ...

# %%
#have to get the unique song and artist pair to find the genre to include the genre ID.
df_1[df_1["Artist"] == "Norah Jones"]["Top Genre"]
# df_1[(df_1["Title"] ==  "Sunrise") & (df_1["Artist"] == "Norah Jones")]["Top Genre"]
#df_1["Title"][0]
#df_1[(df_1["Title"] ==  "Clint Eastwood")]
# Out:
# 0     adult standards
# 33    adult standards
# Name: Top Genre, dtype: object

# %%
df_2 = df[["Artist","Title"]]

# %%
df_1["Top Genre"].value_counts().count()
# Out:
# 149

# %%
df_1[df_1["Artist"] == "Taylor Swift"]
df_1.iloc[0]
# Out:
# Index                                   1
# Artist                        Norah Jones
# Title                             Sunrise
# Top Genre                 adult standards
# Year                                 2004
# Danceability                           53
# Popularity                             71
# Energy                                 30
# Length (Duration)                     201
# Beats Per Minute (BPM)                157
# Name: 0, dtype: object

# %%
Artist_Table = df[["Artist"]]
Genre_Table = df[["Top Genre"]]

# %%
result = pd.concat([Artist_Table, Genre_Table], axis=1)
result
# Out:
#                         Artist            Top Genre
# 0                  Norah Jones      adult standards
# 1                  Deep Purple           album rock
# 2                     Gorillaz  alternative hip hop
# 3                 Foo Fighters    alternative metal
# 4            Bruce Springsteen         classic rock
# ...                        ...                  ...
# 1989             Elvis Presley      adult standards
# 1990             Elvis Presley      adult standards
# 1991               Chuck Berry           blues rock
# 1992  The Dave Brubeck Quartet                bebop
# 1993               Fats Domino      adult standards
#
# [1994 rows x 2 columns]

# %%
#GENRE_ID_TABLE
genre_id_table = df[["Top Genre"]]
#removes the duplicates from genre_id_table
genre_id_table.drop_duplicates(inplace = True)
#assign each genre its own unique ID
genre_id_table.insert(0, "Genre_ID", range(0, 149))
# Out:
# /var/folders/yt/ff8t9qs52f7d88_lbx_lkk2m0000gn/T/ipykernel_10590/2022681586.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3.drop_duplicates(inplace = True)

# %%
# SONG > Genre > Genre is in genre table
#Song File Table
#Index, Artist Name(FK), Song Title, Year, Genre ID(FK)
df_4 = df[["Index", "Artist", "Title", "Year"]] #add genre id col from genre_id_table

# %%
df_4 = df_4.assign(Genre = lambda x: (df_1[(df_1["Title"] == x["Title"]) & (df_1["Artist"] == x["Artist"])]["Top Genre"]))

# %%
df_4
# Out:
#       Index                    Artist                   Title  Year  \
# 0         1               Norah Jones                 Sunrise  2004
# 1         2               Deep Purple             Black Night  2000
# 2         3                  Gorillaz          Clint Eastwood  2001
# 3         4              Foo Fighters           The Pretender  2007
# 4         5         Bruce Springsteen  Waitin' On A Sunny Day  2002
# ...     ...                       ...                     ...   ...
# 1989   1990             Elvis Presley        Heartbreak Hotel  1958
# 1990   1991             Elvis Presley               Hound Dog  1958
# 1991   1992               Chuck Berry         Johnny B. Goode  1959
# 1992   1993  The Dave Brubeck Quartet               Take Five  1959
# 1993   1994               Fats Domino          Blueberry Hill  1959
#
#                     Genre
# 0         adult standards
# 1              album rock
# 2     alternative hip hop
# 3       alternative metal
# ...

# %%
df_4 = df_4.rename(columns = {"Genre" : "Top Genre"})

# %%
# this df_1[(df_1["Title"] == x["Title"]) & (df_1["Artist"] == x["Artist"])]["Top Genre"]) returns the TOP GENRE
#(genre_id_table[genre_id_table["Top Genre"]] == (df_1[(df_1["Title"] == x["Title"]) & (df_1["Artist"] == x["Artist"])]["Top Genre"])["Genre_ID"])
#df_4.assign(Genre_ID = lambda x: (df_1[(df_1["Title"] == x["Title"]) & (df_1["Artist"] == x["Artist"])]["Top Genre"]))
#genre_id_table[genre_id_table["Top Genre"] == "adult standards"]
#df_4.assign(Genre_ID = lambda x: ((genre_id_table[genre_id_table["Top Genre"] == (df_1[(df_1["Title"] == x["Title"]) & (df_1["Artist"] == x["Artist"])])]["Top Genre"])["Genre_ID"]))
#(df_1[(df_1["Title"] == x["Title"]) & (df_1["Artist"] == x["Artist"])]["Top Genre"])
# "adult standards" ==  (df_1[(df_1["Title"] == x["Title"]) & (df_1["Artist"] == x["Artist"])]["Top Genre"]))
#(genre_id_table[genre_id_table["Top Genre"] == "adult standards"])["Genre_ID"]
#(genre_id_table[genre_id_table["Top Genre"] == (df_1[(df_1["Title"] == x["Title"]) & (df_1["Artist"] == x["Artist"])]["Top Genre"])])["Genre_ID"]

#df_4.assign(Genre_ID = lambda x: (genre_id_table[genre_id_table["Top Genre"] == (df_1[(df_1["Title"] == x["Title"]) & (df_1["Artist"] == x["Artist"])]["Top Genre"])])["Genre_ID"])

song_file_table = df_4.merge(genre_id_table)
song_file_table
# Out:
#       Index                           Artist  \
# 0         1                      Norah Jones
# 1        11                    Elvis Presley
# 2        34                      Norah Jones
# 3        49                      Barry White
# 4       125                  The Temptations
# ...     ...                              ...
# 1989   1762                          Liquido
# 1990   1818                         Zucchero
# 1991   1821                        blink-182
# 1992   1881  James Brown & The Famous Flames
# 1993   1993         The Dave Brubeck Quartet
#
#                                           Title  Year  \
# 0                                       Sunrise  2004
# 1                                Love Me Tender  2002
# 2                                Don't Know Why  2002
# 3     You're The First, The Last, My Everything  2009
# 4                      Papa Was A Rolling Stone  2001
# ...                                         ...   ...
# ...

# %%
#SONG NAME ID TABLE
song_name_ID_table = df_1[["Title"]]
song_name_ID_table.insert(0, "song_name_ID", range(0, 1994))
song_name_ID_table
# Out:
#       song_name_ID                   Title
# 0                0                 Sunrise
# 1                1             Black Night
# 2                2          Clint Eastwood
# 3                3           The Pretender
# 4                4  Waitin' On A Sunny Day
# ...            ...                     ...
# 1989          1989        Heartbreak Hotel
# 1990          1990               Hound Dog
# 1991          1991         Johnny B. Goode
# 1992          1992               Take Five
# 1993          1993          Blueberry Hill
#
# [1994 rows x 2 columns]

# %%
#ARTIST ID TABLE
artist_ID_table = df_1[["Artist"]]
artist_ID_table.drop_duplicates(inplace = True)
artist_ID_table.insert(0, "Artist_ID", range(0, 731))
artist_ID_table
# Out:
# /var/folders/yt/ff8t9qs52f7d88_lbx_lkk2m0000gn/T/ipykernel_10590/3827617993.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   artist_ID_table.drop_duplicates(inplace = True)
#       Artist_ID                    Artist
# 0             0               Norah Jones
# 1             1               Deep Purple
# 2             2                  Gorillaz
# 3             3              Foo Fighters
# 4             4         Bruce Springsteen
# ...         ...                       ...
# 1982        726                Rare Earth
# 1984        727     Crosby, Stills & Nash
# 1991        728               Chuck Berry
# 1992        729  The Dave Brubeck Quartet
# 1993        730               Fats Domino
#
# [731 rows x 2 columns]

# %%
'''
Song File Table: df_ 4
Song Name  ID
Song Name
Artist  ID  (FK)
Year
Genre ID  (FK)
Duration 
Beats Per Minute
Danceability 
Popularity 
Energy '''
